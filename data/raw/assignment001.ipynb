# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image
plt.figure(figsize=(20,10))

# %%
#Using open source FAO data which I downloaded from their site: http://www.fao.org/faostat/en/#home
#I want to know how wheat yields in the Netherlands has changed over time so that I can model
#forecasts using ARIMA and Facebook Prophet.

# What I need to do:
# 1. readin data from /mnt/my_mount_point/FAO_Prod.csv
#      Note: you might need to add:  encoding = "ISO-8859-1 (do a Google search) to the code below
# 2. select the Netherlands (think about setting your index to area = "Netherlands")
# 3. now select wheat for the Netherlands (a conditional selection might work)
# 4. now select Element = Yield for wheat in the Netherlands
# 5. remove column if it contains F, try: cols = [c for c in df4.columns if 'F' not in c]
# 6. keep only if column has Y, try: cols = [c for c in cols if 'Y' in c]
# 7. transpose (df.T)
# 8. plot the time series!!!

# %%
df1 = pd.read_csv("/mnt/my_mount_point/FAO_Prod.csv")

# %%
#Your code in cells below, separate sections of your code so that it makes sense
#to you.

# %%
#In the end you should have a picture something like:
Image(filename='NLD_Wheat_Yields.png')
